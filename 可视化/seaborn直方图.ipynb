# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import Series, DataFrame
# %matplotlib inline

# %%
import seaborn as sns

# %%
s1 = Series(np.random.randn(1000))

# %%
plt.hist(s1)
# Out:
# (array([   3.,   30.,   87.,  207.,  274.,  247.,  118.,   25.,    7.,    2.]),
#  array([-3.40058464, -2.66160443, -1.92262422, -1.18364401, -0.4446638 ,
#          0.29431641,  1.03329662,  1.77227683,  2.51125704,  3.25023725,
#          3.98921746]),
#  <a list of 10 Patch objects>)

# %%
s1.plot(kind='kde')

# %%
sns.distplot(s1, bins=20, hist=True, kde=True, rug=True)

# %%
sns.kdeplot(s1, shade=True, color='r')

# %%
sns.rugplot(s1)
